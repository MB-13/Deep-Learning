# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions

# %%
model = ResNet50(weights= 'imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 119s 1us/step

# %%
img_path = r'D:\study\ML\dogs_vs_cats\test\dogs\dog.191.jpg'

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x26C733E8FA0>

# %%
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)
plt.imshow(x.reshape(224,224,3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 153ms/step

# %%
print('Predicted: ',decode_predictions(preds,top=3)[0])
# Out:
# Predicted:  [('n02094114', 'Norfolk_terrier', 0.8581329), ('n02093754', 'Border_terrier', 0.03213041), ('n02094258', 'Norwich_terrier', 0.024969101)]
