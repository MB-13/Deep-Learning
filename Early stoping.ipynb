# %% [markdown]
# Early Stopping :- it is used to stop the overfitting. it stops at that value of weighs and bias when the val_loss on validation data increases.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split 
from sklearn.datasets import make_circles
import seaborn as sns
# Out:
# C:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X , y = make_circles(n_samples = 100 ,noise=0.1,random_state=1)

# %%
sns.scatterplot(X[:,0],X[:,1],hue=y)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
model = Sequential()

model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(loss='binary_crossentropy',optimizer='Adam',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=3500)
# Out:
# Epoch 1/3500
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 1s 127ms/step - loss: 0.6952 - accuracy: 0.5000 - val_loss: 0.6950 - val_accuracy: 0.5000
# Epoch 2/3500
# 3/3 [==============================] - 0s 27ms/step - loss: 0.6932 - accuracy: 0.4625 - val_loss: 0.6980 - val_accuracy: 0.3500
# Epoch 3/3500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.6910 - accuracy: 0.5375 - val_loss: 0.6991 - val_accuracy: 0.4500
# Epoch 4/3500
# ...

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.legend()
plt.show()

# %% [markdown]
# after around 300 epochs val_loss increases and we can see that overfitting is in the picture---> to stop after best epochs value EARLYSTOPPING is used

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x_test,y_test.ravel(),clf=model,legend=2)
plt.show()
# Out:
# 3888/3888 [==============================] - 7s 2ms/step

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor = 'val_loss',
    min_delta = 0.00001,
    patience = 20,
    verbose = 1,
    mode='auto',
    baseline = None,
    restore_best_weights = True
)

# %%
history = model.fit(x_train,y_train,validation_data = (x_test,y_test), epochs=3500,callbacks = callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 0s 45ms/step - loss: 0.3314 - accuracy: 0.8750 - val_loss: 0.5769 - val_accuracy: 0.6000
# Epoch 2/3500
# 3/3 [==============================] - 0s 28ms/step - loss: 0.3299 - accuracy: 0.8750 - val_loss: 0.5749 - val_accuracy: 0.6000
# Epoch 3/3500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3296 - accuracy: 0.8750 - val_loss: 0.5744 - val_accuracy: 0.6000
# Epoch 4/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3287 - accuracy: 0.8750 - val_loss: 0.5741 - val_accuracy: 0.6000
# Epoch 5/3500
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3280 - accuracy: 0.8750 - val_loss: 0.5774 - val_accuracy: 0.6500
# Epoch 6/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3279 - accuracy: 0.8750 - val_loss: 0.5797 - val_accuracy: 0.6500
# Epoch 7/3500
# ...

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(x_test,y_test.ravel(),clf=model,legend=2)
plt.show()
# Out:
# 3888/3888 [==============================] - 7s 2ms/step
