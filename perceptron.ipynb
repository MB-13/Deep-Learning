# %%
from sklearn.datasets import make_classification
import numpy as np
import matplotlib.pyplot as plt
X,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=15)

# %%
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter')

# %% [markdown]
# # PERCEPTRON USING TRICK(not give accurate ans)

# %% [raw]
# The idea behind this trick method is that, some initial values form weights are taken like all ones and which these weights y_hat is calculated by selecting the random input point.
# if the prediction is wrong:
#     if negative point is in positive region:
#         weights = weights - lr*X[j](learning rate X coordinate of selected point)
#     if positive point is in negative region:
#         weights = weights + lr*X[j](lr*coordinate of selected point)
# if correct:
#     Do nothing
# this operation will shift line in such a way that this point will come in correct region

# %%
def perceptron(X,y):
    X = np.insert(X,1,0,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.01
    
    for i in range (1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
def step(Z):
    return 1 if Z>0 else 0

# %%
intercept_,coeff_ = perceptron(X,y)

# %%
intercept_
# Out:
# 0.9150192891708314

# %%
coeff_
# Out:
# array([1.        , 0.06744973])

# %%
m = -(coeff_[0]/coeff_[1])
b = -(intercept_/coeff_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure()
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter')
plt.show()

# %% [markdown]
# # PERCEPTRON USING LOSS FUNCTION(original method)

# %%
def perceptron(X,y):
    
    w1=w2=b=1
    lr =0.1
    
    for j in range(1000):
        
        for i in range(X.shape[0]):
            
            #check condition
            z = w1*X[i][0]+w2*X[i][1]+b
            
            if z*y[i] <0:
                w1 = w1 + lr*y[i]*X[i][0]
                w2 = w2 + lr*y[i]*X[i][1]
                b = b + lr*y[i]
                
    slope = -(w1/w2)
    intercept = -(b/w2)
                
    return w1,w2,b,slope,intercept

# %% [raw]
# dL/dw1 = 0   if yi*f(xi) >= 0        #do noting as in correct place
#          -yi*xi1   if yi*f(xi) < 0   #update w1
#
# dL/dw2 = 0   if yi*f(xi) >= 0        #do noting as in correct place
#          -yi*xi2   if yi*f(xi) < 0   #update w2
#
# dL/db = 0   if yi*f(xi) >= 0         #do noting as in correct place
#          -yi   if yi*f(xi) < 0       #update b

# %%
w1,w2,b,slope,intercept= perceptron(X,y)

# %%
w1
# Out:
# 1.006638570722407

# %%
w2
# Out:
# 0.22215119727529098

# %%
b
# Out:
# 1.3000000000000003

# %%
slope
# Out:
# -4.531321834268464

# %%
intercept
# Out:
# -5.851870329508209

# %%
# Y = Mx + C  M->slope  C-> intercept

# %%
x_input = np.linspace(-3,3,100)
y_input = slope*x_input + intercept

# %% [raw]
# The problem with this perceptron is that it can only used in linear datasets and not in higher degree datasets.
# This thing is solved using multiple perceptron forming a Multi Layer Perceptron.
