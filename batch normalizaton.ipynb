# %% [raw]
# Batch Normalization :- it is a approach in which each layer in neural network is transformed into normallized distribution for better performance and convergence.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import make_circles

# %%
X,y = make_circles(n_samples=200,noise=0.3,factor=0.2)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,BatchNormalization

# %%
model_1 = Sequential()

model_1.add(Dense(2,activation='relu',input_dim=2))
model_1.add(Dense(2,activation='relu'))
model_1.add(Dense(1,activation='sigmoid'))

model_1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 2)                 6
#
#  dense_7 (Dense)             (None, 2)                 6
#
#  dense_8 (Dense)             (None, 1)                 3
#
# ...
# Total params: 15 (60.00 Byte)
# Trainable params: 15 (60.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_1.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history1 = model_1.fit(X,y,validation_split=0.2,epochs=200)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 38ms/step - loss: 0.7654 - accuracy: 0.4437 - val_loss: 0.7380 - val_accuracy: 0.5250
# Epoch 2/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7622 - accuracy: 0.4375 - val_loss: 0.7370 - val_accuracy: 0.5500
# Epoch 3/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7602 - accuracy: 0.4187 - val_loss: 0.7362 - val_accuracy: 0.5500
# Epoch 4/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7573 - accuracy: 0.4125 - val_loss: 0.7353 - val_accuracy: 0.5250
# Epoch 5/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7552 - accuracy: 0.4000 - val_loss: 0.7345 - val_accuracy: 0.5250
# Epoch 6/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7526 - accuracy: 0.3688 - val_loss: 0.7338 - val_accuracy: 0.5250
# Epoch 7/200
# ...

# %%
model_2 = Sequential()

model_2.add(Dense(2,activation='relu',input_dim=2))
model_2.add(BatchNormalization())
model_2.add(Dense(2,activation='relu'))
model_2.add(BatchNormalization())
model_2.add(Dense(1,activation='sigmoid'))

model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 2)                 6
#
#  batch_normalization_2 (Bat  (None, 2)                 8
#  chNormalization)
#
#  dense_10 (Dense)            (None, 2)                 6
#
#  batch_normalization_3 (Bat  (None, 2)                 8
#  chNormalization)
#
#  dense_11 (Dense)            (None, 1)                 3
#
# ...
# Total params: 31 (124.00 Byte)
# Trainable params: 23 (92.00 Byte)
# Non-trainable params: 8 (32.00 Byte)
# _________________________________________________________________

# %%
model_2.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
history2 = model_2.fit(X,y,validation_split=0.2,epochs=200)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 51ms/step - loss: 0.6900 - accuracy: 0.6062 - val_loss: 0.6945 - val_accuracy: 0.4250
# Epoch 2/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6867 - accuracy: 0.6000 - val_loss: 0.6955 - val_accuracy: 0.4250
# Epoch 3/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6958 - accuracy: 0.6062 - val_loss: 0.6963 - val_accuracy: 0.4250
# Epoch 4/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7124 - accuracy: 0.5875 - val_loss: 0.6966 - val_accuracy: 0.4250
# Epoch 5/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6846 - accuracy: 0.6000 - val_loss: 0.6967 - val_accuracy: 0.4250
# Epoch 6/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6888 - accuracy: 0.6000 - val_loss: 0.6969 - val_accuracy: 0.4250
# Epoch 7/200
# ...

# %%
plt.plot(history1.history['val_accuracy'],color='black')
plt.plot(history2.history['val_accuracy'],color = 'red')

# %% [markdown]
# As you can see here, red graph is for batch normalization which gives more val_accuracy and faster performance
